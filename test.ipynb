# %%
import torch
import random
import numpy as np
import matplotlib as plt

# %%
torch.manual_seed(42)

x = torch.randn(2, 10)
w = torch.randn(10, 3)
b = torch.randn(3)

y = x @ w + b

torch.sigmoid(y)
# Out:
# tensor([[0.2835, 0.6127, 0.1396],
#         [0.8919, 0.1804, 0.0321]])
